# %% [markdown]
# # PRUEBAS API

# %% [markdown]
# ## Prueba Partidos Premier League JSON

# %%
import requests
# Define the API endpoint and your API token
api_url = 'https://api.football-data.org/v4/competitions/PL/matches'
headers = {'X-Auth-Token': '9b3bba4a9ab24ab68b70aac4677adbbe'}  # Replace with your actual API token

# Send a GET request to the API
response = requests.get(api_url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    # Extracting matches data
    matches = data.get('matches', [])
    
    # Displaying the latest results
    for match in matches:
        home_team = match['homeTeam']['name']
        away_team = match['awayTeam']['name']
        score = match['score']
        home_score = score['fullTime']['home']
        away_score = score['fullTime']['away']
        status = match['status']
        
        print(f"{home_team} {home_score} - {away_score} {away_team} ({status})")
else:
    print(f"Request failed with status code {response.status_code}: {response.text}")
# Out:
# Manchester United FC 1 - 0 Fulham FC (FINISHED)
# Ipswich Town FC 0 - 2 Liverpool FC (FINISHED)
# Arsenal FC 2 - 0 Wolverhampton Wanderers FC (FINISHED)
# Everton FC 0 - 3 Brighton & Hove Albion FC (FINISHED)
# Newcastle United FC 1 - 0 Southampton FC (FINISHED)
# Nottingham Forest FC 1 - 1 AFC Bournemouth (FINISHED)
# West Ham United FC 1 - 2 Aston Villa FC (FINISHED)
# Brentford FC 2 - 1 Crystal Palace FC (FINISHED)
# Chelsea FC 0 - 2 Manchester City FC (FINISHED)
# Leicester City FC 1 - 1 Tottenham Hotspur FC (FINISHED)
# Brighton & Hove Albion FC 2 - 1 Manchester United FC (FINISHED)
# Crystal Palace FC 0 - 2 West Ham United FC (FINISHED)
# Fulham FC 2 - 1 Leicester City FC (FINISHED)
# Manchester City FC 4 - 1 Ipswich Town FC (FINISHED)
# Southampton FC 0 - 1 Nottingham Forest FC (FINISHED)
# Tottenham Hotspur FC 4 - 0 Everton FC (FINISHED)
# Aston Villa FC 0 - 2 Arsenal FC (FINISHED)
# AFC Bournemouth 1 - 1 Newcastle United FC (FINISHED)
# Wolverhampton Wanderers FC 2 - 6 Chelsea FC (FINISHED)
# Liverpool FC 2 - 0 Brentford FC (FINISHED)
# Arsenal FC 1 - 1 Brighton & Hove Albion FC (FINISHED)
# Brentford FC 3 - 1 Southampton FC (FINISHED)
# Everton FC 2 - 3 AFC Bournemouth (FINISHED)
# Ipswich Town FC 1 - 1 Fulham FC (FINISHED)
# Leicester City FC 1 - 2 Aston Villa FC (FINISHED)
# Nottingham Forest FC 1 - 1 Wolverhampton Wanderers FC (FINISHED)
# West Ham United FC 1 - 3 Manchester City FC (FINISHED)
# Chelsea FC 1 - 1 Crystal Palace FC (FINISHED)
# Newcastle United FC 2 - 1 Tottenham Hotspur FC (FINISHED)
# Manchester United FC 0 - 3 Liverpool FC (FINISHED)
# Southampton FC 0 - 3 Manchester United FC (FINISHED)
# Brighton & Hove Albion FC 0 - 0 Ipswich Town FC (FINISHED)
# Crystal Palace FC 2 - 2 Leicester City FC (FINISHED)
# Fulham FC 1 - 1 West Ham United FC (FINISHED)
# Liverpool FC 0 - 1 Nottingham Forest FC (FINISHED)
# Manchester City FC 2 - 1 Brentford FC (FINISHED)
# Aston Villa FC 3 - 2 Everton FC (FINISHED)
# AFC Bournemouth 0 - 1 Chelsea FC (FINISHED)
# Tottenham Hotspur FC 0 - 1 Arsenal FC (FINISHED)
# Wolverhampton Wanderers FC 1 - 2 Newcastle United FC (FINISHED)
# West Ham United FC 0 - 3 Chelsea FC (FINISHED)
# Aston Villa FC 3 - 1 Wolverhampton Wanderers FC (FINISHED)
# Fulham FC 3 - 1 Newcastle United FC (FINISHED)
# Leicester City FC 1 - 1 Everton FC (FINISHED)
# Liverpool FC 3 - 0 AFC Bournemouth (FINISHED)
# Southampton FC 1 - 1 Ipswich Town FC (FINISHED)
# Tottenham Hotspur FC 3 - 1 Brentford FC (FINISHED)
# Crystal Palace FC 0 - 0 Manchester United FC (FINISHED)
# Brighton & Hove Albion FC 2 - 2 Nottingham Forest FC (FINISHED)
# Manchester City FC 2 - 2 Arsenal FC (FINISHED)
# Newcastle United FC 1 - 1 Manchester City FC (FINISHED)
# Arsenal FC 4 - 2 Leicester City FC (FINISHED)
# Brentford FC 1 - 1 West Ham United FC (FINISHED)
# Chelsea FC 4 - 2 Brighton & Hove Albion FC (FINISHED)
# Everton FC 2 - 1 Crystal Palace FC (FINISHED)
# Nottingham Forest FC 0 - 1 Fulham FC (FINISHED)
# Wolverhampton Wanderers FC 1 - 2 Liverpool FC (FINISHED)
# Ipswich Town FC 2 - 2 Aston Villa FC (FINISHED)
# Manchester United FC 0 - 3 Tottenham Hotspur FC (FINISHED)
# AFC Bournemouth 3 - 1 Southampton FC (FINISHED)
# Crystal Palace FC 0 - 1 Liverpool FC (FINISHED)
# Arsenal FC 3 - 1 Southampton FC (FINISHED)
# Brentford FC 5 - 3 Wolverhampton Wanderers FC (FINISHED)
# Leicester City FC 1 - 0 AFC Bournemouth (FINISHED)
# Manchester City FC 3 - 2 Fulham FC (FINISHED)
# West Ham United FC 4 - 1 Ipswich Town FC (FINISHED)
# Everton FC 0 - 0 Newcastle United FC (FINISHED)
# Aston Villa FC 0 - 0 Manchester United FC (FINISHED)
# Chelsea FC 1 - 1 Nottingham Forest FC (FINISHED)
# Brighton & Hove Albion FC 3 - 2 Tottenham Hotspur FC (FINISHED)
# Tottenham Hotspur FC 4 - 1 West Ham United FC (FINISHED)
# Fulham FC 1 - 3 Aston Villa FC (FINISHED)
# Ipswich Town FC 0 - 2 Everton FC (FINISHED)
# Manchester United FC 2 - 1 Brentford FC (FINISHED)
# Newcastle United FC 0 - 1 Brighton & Hove Albion FC (FINISHED)
# Southampton FC 2 - 3 Leicester City FC (FINISHED)
# AFC Bournemouth 2 - 0 Arsenal FC (FINISHED)
# Wolverhampton Wanderers FC 1 - 2 Manchester City FC (FINISHED)
# Liverpool FC 2 - 1 Chelsea FC (FINISHED)
# Nottingham Forest FC 1 - 0 Crystal Palace FC (FINISHED)
# Leicester City FC 1 - 3 Nottingham Forest FC (FINISHED)
# Aston Villa FC 1 - 1 AFC Bournemouth (FINISHED)
# Brentford FC 4 - 3 Ipswich Town FC (FINISHED)
# Brighton & Hove Albion FC 2 - 2 Wolverhampton Wanderers FC (FINISHED)
# Manchester City FC 1 - 0 Southampton FC (FINISHED)
# Everton FC 1 - 1 Fulham FC (FINISHED)
# Chelsea FC 2 - 1 Newcastle United FC (FINISHED)
# Crystal Palace FC 1 - 0 Tottenham Hotspur FC (FINISHED)
# West Ham United FC 2 - 1 Manchester United FC (FINISHED)
# Arsenal FC 2 - 2 Liverpool FC (FINISHED)
# Newcastle United FC 1 - 0 Arsenal FC (FINISHED)
# AFC Bournemouth 2 - 1 Manchester City FC (FINISHED)
# Ipswich Town FC 1 - 1 Leicester City FC (FINISHED)
# Liverpool FC 2 - 1 Brighton & Hove Albion FC (FINISHED)
# Nottingham Forest FC 3 - 0 West Ham United FC (FINISHED)
# Southampton FC 1 - 0 Everton FC (FINISHED)
# Wolverhampton Wanderers FC 2 - 2 Crystal Palace FC (FINISHED)
# Tottenham Hotspur FC 4 - 1 Aston Villa FC (FINISHED)
# Manchester United FC 1 - 1 Chelsea FC (FINISHED)
# Fulham FC 2 - 1 Brentford FC (FINISHED)
# Brentford FC 3 - 2 AFC Bournemouth (FINISHED)
# Crystal Palace FC 0 - 2 Fulham FC (FINISHED)
# West Ham United FC 0 - 0 Everton FC (FINISHED)
# Wolverhampton Wanderers FC 2 - 0 Southampton FC (FINISHED)
# Brighton & Hove Albion FC 2 - 1 Manchester City FC (FINISHED)
# Liverpool FC 2 - 0 Aston Villa FC (FINISHED)
# Manchester United FC 3 - 0 Leicester City FC (FINISHED)
# Nottingham Forest FC 1 - 3 Newcastle United FC (FINISHED)
# Tottenham Hotspur FC 1 - 2 Ipswich Town FC (FINISHED)
# Chelsea FC 1 - 1 Arsenal FC (FINISHED)
# Leicester City FC 1 - 2 Chelsea FC (FINISHED)
# AFC Bournemouth 1 - 2 Brighton & Hove Albion FC (FINISHED)
# Arsenal FC 3 - 0 Nottingham Forest FC (FINISHED)
# Aston Villa FC 2 - 2 Crystal Palace FC (FINISHED)
# Everton FC 0 - 0 Brentford FC (FINISHED)
# Fulham FC 1 - 4 Wolverhampton Wanderers FC (FINISHED)
# Manchester City FC 0 - 4 Tottenham Hotspur FC (FINISHED)
# Southampton FC 2 - 3 Liverpool FC (FINISHED)
# Ipswich Town FC 1 - 1 Manchester United FC (FINISHED)
# Newcastle United FC 0 - 2 West Ham United FC (FINISHED)
# Brighton & Hove Albion FC 1 - 1 Southampton FC (FINISHED)
# Brentford FC 4 - 1 Leicester City FC (FINISHED)
# Crystal Palace FC 1 - 1 Newcastle United FC (FINISHED)
# Nottingham Forest FC 1 - 0 Ipswich Town FC (FINISHED)
# Wolverhampton Wanderers FC 2 - 4 AFC Bournemouth (FINISHED)
# West Ham United FC 2 - 5 Arsenal FC (FINISHED)
# Chelsea FC 3 - 0 Aston Villa FC (FINISHED)
# Manchester United FC 4 - 0 Everton FC (FINISHED)
# Tottenham Hotspur FC 1 - 1 Fulham FC (FINISHED)
# Liverpool FC 2 - 0 Manchester City FC (FINISHED)
# Ipswich Town FC 0 - 1 Crystal Palace FC (FINISHED)
# Leicester City FC 3 - 1 West Ham United FC (FINISHED)
# Everton FC 4 - 0 Wolverhampton Wanderers FC (FINISHED)
# Manchester City FC 3 - 0 Nottingham Forest FC (FINISHED)
# Newcastle United FC 3 - 3 Liverpool FC (FINISHED)
# Southampton FC 1 - 5 Chelsea FC (FINISHED)
# Arsenal FC 2 - 0 Manchester United FC (FINISHED)
# Aston Villa FC 3 - 1 Brentford FC (FINISHED)
# Fulham FC 3 - 1 Brighton & Hove Albion FC (FINISHED)
# AFC Bournemouth 1 - 0 Tottenham Hotspur FC (FINISHED)
# Aston Villa FC 1 - 0 Southampton FC (FINISHED)
# Brentford FC 4 - 2 Newcastle United FC (FINISHED)
# Crystal Palace FC 2 - 2 Manchester City FC (FINISHED)
# Manchester United FC 2 - 3 Nottingham Forest FC (FINISHED)
# Fulham FC 1 - 1 Arsenal FC (FINISHED)
# Ipswich Town FC 1 - 2 AFC Bournemouth (FINISHED)
# Leicester City FC 2 - 2 Brighton & Hove Albion FC (FINISHED)
# Tottenham Hotspur FC 3 - 4 Chelsea FC (FINISHED)
# West Ham United FC 2 - 1 Wolverhampton Wanderers FC (FINISHED)
# Arsenal FC 0 - 0 Everton FC (FINISHED)
# Liverpool FC 2 - 2 Fulham FC (FINISHED)
# Newcastle United FC 4 - 0 Leicester City FC (FINISHED)
# Wolverhampton Wanderers FC 1 - 2 Ipswich Town FC (FINISHED)
# Nottingham Forest FC 2 - 1 Aston Villa FC (FINISHED)
# Brighton & Hove Albion FC 1 - 3 Crystal Palace FC (FINISHED)
# Manchester City FC 1 - 2 Manchester United FC (FINISHED)
# Chelsea FC 2 - 1 Brentford FC (FINISHED)
# Southampton FC 0 - 5 Tottenham Hotspur FC (FINISHED)
# AFC Bournemouth 1 - 1 West Ham United FC (FINISHED)
# Aston Villa FC 2 - 1 Manchester City FC (FINISHED)
# Brentford FC 0 - 2 Nottingham Forest FC (FINISHED)
# Ipswich Town FC 0 - 4 Newcastle United FC (FINISHED)
# West Ham United FC 1 - 1 Brighton & Hove Albion FC (FINISHED)
# Crystal Palace FC 1 - 5 Arsenal FC (FINISHED)
# Everton FC 0 - 0 Chelsea FC (FINISHED)
# Fulham FC 0 - 0 Southampton FC (FINISHED)
# Leicester City FC 0 - 3 Wolverhampton Wanderers FC (FINISHED)
# Manchester United FC 0 - 3 AFC Bournemouth (FINISHED)
# Tottenham Hotspur FC 3 - 6 Liverpool FC (FINISHED)
# Manchester City FC 1 - 1 Everton FC (FINISHED)
# AFC Bournemouth 0 - 0 Crystal Palace FC (FINISHED)
# Chelsea FC 1 - 2 Fulham FC (FINISHED)
# Newcastle United FC 3 - 0 Aston Villa FC (FINISHED)
# Nottingham Forest FC 1 - 0 Tottenham Hotspur FC (FINISHED)
# Southampton FC 0 - 1 West Ham United FC (FINISHED)
# Wolverhampton Wanderers FC 2 - 0 Manchester United FC (FINISHED)
# Liverpool FC 3 - 1 Leicester City FC (FINISHED)
# Brighton & Hove Albion FC 0 - 0 Brentford FC (FINISHED)
# Arsenal FC 1 - 0 Ipswich Town FC (FINISHED)
# Leicester City FC 0 - 2 Manchester City FC (FINISHED)
# Crystal Palace FC 2 - 1 Southampton FC (FINISHED)
# Everton FC 0 - 2 Nottingham Forest FC (FINISHED)
# Fulham FC 2 - 2 AFC Bournemouth (FINISHED)
# Tottenham Hotspur FC 2 - 2 Wolverhampton Wanderers FC (FINISHED)
# West Ham United FC 0 - 5 Liverpool FC (FINISHED)
# Aston Villa FC 2 - 2 Brighton & Hove Albion FC (FINISHED)
# Ipswich Town FC 2 - 0 Chelsea FC (FINISHED)
# Manchester United FC 0 - 2 Newcastle United FC (FINISHED)
# Brentford FC 1 - 3 Arsenal FC (FINISHED)
# Tottenham Hotspur FC 1 - 2 Newcastle United FC (FINISHED)
# Southampton FC 0 - 5 Brentford FC (FINISHED)
# Crystal Palace FC 1 - 1 Chelsea FC (FINISHED)
# AFC Bournemouth 1 - 0 Everton FC (FINISHED)
# Aston Villa FC 2 - 1 Leicester City FC (FINISHED)
# Manchester City FC 4 - 1 West Ham United FC (FINISHED)
# Brighton & Hove Albion FC 1 - 1 Arsenal FC (FINISHED)
# Fulham FC 2 - 2 Ipswich Town FC (FINISHED)
# Liverpool FC 2 - 2 Manchester United FC (FINISHED)
# Wolverhampton Wanderers FC 0 - 3 Nottingham Forest FC (FINISHED)
# West Ham United FC 3 - 2 Fulham FC (FINISHED)
# Brentford FC 2 - 2 Manchester City FC (FINISHED)
# Chelsea FC 2 - 2 AFC Bournemouth (FINISHED)
# Nottingham Forest FC 1 - 1 Liverpool FC (FINISHED)
# Everton FC 0 - 1 Aston Villa FC (FINISHED)
# Leicester City FC 0 - 2 Crystal Palace FC (FINISHED)
# Newcastle United FC 3 - 0 Wolverhampton Wanderers FC (FINISHED)
# Arsenal FC 2 - 1 Tottenham Hotspur FC (FINISHED)
# Ipswich Town FC 0 - 2 Brighton & Hove Albion FC (FINISHED)
# Manchester United FC 3 - 1 Southampton FC (FINISHED)
# Newcastle United FC 1 - 4 AFC Bournemouth (FINISHED)
# West Ham United FC 0 - 2 Crystal Palace FC (FINISHED)
# Leicester City FC 0 - 2 Fulham FC (FINISHED)
# Brentford FC 0 - 2 Liverpool FC (FINISHED)
# Arsenal FC 2 - 2 Aston Villa FC (FINISHED)
# Manchester United FC 1 - 3 Brighton & Hove Albion FC (FINISHED)
# Nottingham Forest FC 3 - 2 Southampton FC (FINISHED)
# Everton FC 3 - 2 Tottenham Hotspur FC (FINISHED)
# Ipswich Town FC 0 - 6 Manchester City FC (FINISHED)
# Chelsea FC 3 - 1 Wolverhampton Wanderers FC (FINISHED)
# Liverpool FC 4 - 1 Ipswich Town FC (FINISHED)
# Wolverhampton Wanderers FC 0 - 1 Arsenal FC (FINISHED)
# Brighton & Hove Albion FC 0 - 1 Everton FC (FINISHED)
# Southampton FC 1 - 3 Newcastle United FC (FINISHED)
# AFC Bournemouth 5 - 0 Nottingham Forest FC (FINISHED)
# Manchester City FC 3 - 1 Chelsea FC (FINISHED)
# Crystal Palace FC 1 - 2 Brentford FC (FINISHED)
# Tottenham Hotspur FC 1 - 2 Leicester City FC (FINISHED)
# Aston Villa FC 1 - 1 West Ham United FC (FINISHED)
# Fulham FC 0 - 1 Manchester United FC (FINISHED)
# Nottingham Forest FC 7 - 0 Brighton & Hove Albion FC (FINISHED)
# Newcastle United FC 1 - 2 Fulham FC (FINISHED)
# Everton FC 4 - 0 Leicester City FC (FINISHED)
# AFC Bournemouth 0 - 2 Liverpool FC (FINISHED)
# Ipswich Town FC 1 - 2 Southampton FC (FINISHED)
# Wolverhampton Wanderers FC 2 - 0 Aston Villa FC (FINISHED)
# Manchester United FC 0 - 2 Crystal Palace FC (FINISHED)
# Brentford FC 0 - 2 Tottenham Hotspur FC (FINISHED)
# Arsenal FC 5 - 1 Manchester City FC (FINISHED)
# Chelsea FC 2 - 1 West Ham United FC (FINISHED)
# Everton FC 2 - 2 Liverpool FC (FINISHED)
# Brighton & Hove Albion FC 3 - 0 Chelsea FC (FINISHED)
# Leicester City FC 0 - 2 Arsenal FC (FINISHED)
# Southampton FC 1 - 3 AFC Bournemouth (FINISHED)
# West Ham United FC 0 - 1 Brentford FC (FINISHED)
# Aston Villa FC 1 - 1 Ipswich Town FC (FINISHED)
# Manchester City FC 4 - 0 Newcastle United FC (FINISHED)
# Fulham FC 2 - 1 Nottingham Forest FC (FINISHED)
# Crystal Palace FC 1 - 2 Everton FC (FINISHED)
# Liverpool FC 2 - 1 Wolverhampton Wanderers FC (FINISHED)
# Tottenham Hotspur FC 1 - 0 Manchester United FC (FINISHED)
# Aston Villa FC 2 - 2 Liverpool FC (FINISHED)
# Leicester City FC 0 - 4 Brentford FC (FINISHED)
# Everton FC 2 - 2 Manchester United FC (FINISHED)
# Ipswich Town FC 1 - 4 Tottenham Hotspur FC (FINISHED)
# Fulham FC 0 - 2 Crystal Palace FC (FINISHED)
# Arsenal FC 0 - 1 West Ham United FC (FINISHED)
# AFC Bournemouth 0 - 1 Wolverhampton Wanderers FC (FINISHED)
# Southampton FC 0 - 4 Brighton & Hove Albion FC (FINISHED)
# Aston Villa FC 2 - 1 Chelsea FC (FINISHED)
# Newcastle United FC 4 - 3 Nottingham Forest FC (FINISHED)
# Manchester City FC 0 - 2 Liverpool FC (FINISHED)
# Brighton & Hove Albion FC 2 - 1 AFC Bournemouth (FINISHED)
# Crystal Palace FC 4 - 1 Aston Villa FC (FINISHED)
# Wolverhampton Wanderers FC 1 - 2 Fulham FC (FINISHED)
# Chelsea FC 4 - 0 Southampton FC (FINISHED)
# Nottingham Forest FC 0 - 0 Arsenal FC (FINISHED)
# Brentford FC 1 - 1 Everton FC (FINISHED)
# Tottenham Hotspur FC 0 - 1 Manchester City FC (FINISHED)
# Manchester United FC 3 - 2 Ipswich Town FC (FINISHED)
# Liverpool FC 2 - 0 Newcastle United FC (FINISHED)
# West Ham United FC 2 - 0 Leicester City FC (FINISHED)
# Nottingham Forest FC 1 - 0 Manchester City FC (FINISHED)
# Brighton & Hove Albion FC 2 - 1 Fulham FC (FINISHED)
# Crystal Palace FC 1 - 0 Ipswich Town FC (FINISHED)
# Liverpool FC 3 - 1 Southampton FC (FINISHED)
# Brentford FC 0 - 1 Aston Villa FC (FINISHED)
# Wolverhampton Wanderers FC 1 - 1 Everton FC (FINISHED)
# Tottenham Hotspur FC 2 - 2 AFC Bournemouth (FINISHED)
# Chelsea FC 1 - 0 Leicester City FC (FINISHED)
# Manchester United FC 1 - 1 Arsenal FC (FINISHED)
# West Ham United FC 0 - 1 Newcastle United FC (FINISHED)
# Everton FC 1 - 1 West Ham United FC (FINISHED)
# Ipswich Town FC 2 - 4 Nottingham Forest FC (FINISHED)
# Manchester City FC 2 - 2 Brighton & Hove Albion FC (FINISHED)
# Southampton FC 1 - 2 Wolverhampton Wanderers FC (FINISHED)
# AFC Bournemouth 1 - 2 Brentford FC (FINISHED)
# Arsenal FC 1 - 0 Chelsea FC (FINISHED)
# Fulham FC 2 - 0 Tottenham Hotspur FC (FINISHED)
# Leicester City FC 0 - 3 Manchester United FC (FINISHED)
# Arsenal FC 2 - 1 Fulham FC (FINISHED)
# Wolverhampton Wanderers FC 1 - 0 West Ham United FC (FINISHED)
# Nottingham Forest FC 1 - 0 Manchester United FC (FINISHED)
# AFC Bournemouth None - None Ipswich Town FC (TIMED)
# Brighton & Hove Albion FC None - None Aston Villa FC (TIMED)
# Manchester City FC None - None Leicester City FC (TIMED)
# Newcastle United FC None - None Brentford FC (TIMED)
# Southampton FC None - None Crystal Palace FC (TIMED)
# Liverpool FC None - None Everton FC (TIMED)
# Chelsea FC None - None Tottenham Hotspur FC (TIMED)
# Everton FC None - None Arsenal FC (TIMED)
# Crystal Palace FC None - None Brighton & Hove Albion FC (TIMED)
# Ipswich Town FC None - None Wolverhampton Wanderers FC (TIMED)
# West Ham United FC None - None AFC Bournemouth (TIMED)
# Aston Villa FC None - None Nottingham Forest FC (TIMED)
# Brentford FC None - None Chelsea FC (TIMED)
# Fulham FC None - None Liverpool FC (TIMED)
# Tottenham Hotspur FC None - None Southampton FC (TIMED)
# Manchester United FC None - None Manchester City FC (TIMED)
# Leicester City FC None - None Newcastle United FC (TIMED)
# Manchester City FC None - None Crystal Palace FC (TIMED)
# Brighton & Hove Albion FC None - None Leicester City FC (TIMED)
# Nottingham Forest FC None - None Everton FC (TIMED)
# Southampton FC None - None Aston Villa FC (TIMED)
# Arsenal FC None - None Brentford FC (TIMED)
# Chelsea FC None - None Ipswich Town FC (TIMED)
# Liverpool FC None - None West Ham United FC (TIMED)
# Wolverhampton Wanderers FC None - None Tottenham Hotspur FC (TIMED)
# Newcastle United FC None - None Manchester United FC (TIMED)
# AFC Bournemouth None - None Fulham FC (TIMED)
# Newcastle United FC None - None Crystal Palace FC (TIMED)
# Brentford FC None - None Brighton & Hove Albion FC (TIMED)
# Crystal Palace FC None - None AFC Bournemouth (TIMED)
# Everton FC None - None Manchester City FC (TIMED)
# West Ham United FC None - None Southampton FC (TIMED)
# Aston Villa FC None - None Newcastle United FC (TIMED)
# Fulham FC None - None Chelsea FC (TIMED)
# Ipswich Town FC None - None Arsenal FC (TIMED)
# Manchester United FC None - None Wolverhampton Wanderers FC (TIMED)
# Leicester City FC None - None Liverpool FC (TIMED)
# Tottenham Hotspur FC None - None Nottingham Forest FC (TIMED)
# Chelsea FC None - None Everton FC (TIMED)
# Brighton & Hove Albion FC None - None West Ham United FC (TIMED)
# Newcastle United FC None - None Ipswich Town FC (TIMED)
# Nottingham Forest FC None - None Brentford FC (TIMED)
# Southampton FC None - None Fulham FC (TIMED)
# Wolverhampton Wanderers FC None - None Leicester City FC (TIMED)
# Arsenal FC None - None Crystal Palace FC (TIMED)
# AFC Bournemouth None - None Manchester United FC (TIMED)
# Liverpool FC None - None Tottenham Hotspur FC (TIMED)
# Manchester City FC None - None Aston Villa FC (TIMED)
# Manchester City FC None - None Wolverhampton Wanderers FC (TIMED)
# Aston Villa FC None - None Fulham FC (TIMED)
# Brentford FC None - None Manchester United FC (TIMED)
# Everton FC None - None Ipswich Town FC (TIMED)
# Leicester City FC None - None Southampton FC (TIMED)
# West Ham United FC None - None Tottenham Hotspur FC (TIMED)
# Arsenal FC None - None AFC Bournemouth (TIMED)
# Brighton & Hove Albion FC None - None Newcastle United FC (TIMED)
# Chelsea FC None - None Liverpool FC (TIMED)
# Crystal Palace FC None - None Nottingham Forest FC (TIMED)
# AFC Bournemouth None - None Aston Villa FC (SCHEDULED)
# Fulham FC None - None Everton FC (SCHEDULED)
# Ipswich Town FC None - None Brentford FC (SCHEDULED)
# Liverpool FC None - None Arsenal FC (SCHEDULED)
# Manchester United FC None - None West Ham United FC (SCHEDULED)
# Newcastle United FC None - None Chelsea FC (SCHEDULED)
# Nottingham Forest FC None - None Leicester City FC (SCHEDULED)
# Southampton FC None - None Manchester City FC (SCHEDULED)
# Tottenham Hotspur FC None - None Crystal Palace FC (SCHEDULED)
# Wolverhampton Wanderers FC None - None Brighton & Hove Albion FC (SCHEDULED)
# Arsenal FC None - None Newcastle United FC (SCHEDULED)
# Aston Villa FC None - None Tottenham Hotspur FC (SCHEDULED)
# Brentford FC None - None Fulham FC (SCHEDULED)
# Brighton & Hove Albion FC None - None Liverpool FC (SCHEDULED)
# Chelsea FC None - None Manchester United FC (SCHEDULED)
# Crystal Palace FC None - None Wolverhampton Wanderers FC (SCHEDULED)
# Everton FC None - None Southampton FC (SCHEDULED)
# Leicester City FC None - None Ipswich Town FC (SCHEDULED)
# Manchester City FC None - None AFC Bournemouth (SCHEDULED)
# West Ham United FC None - None Nottingham Forest FC (SCHEDULED)
# AFC Bournemouth None - None Leicester City FC (TIMED)
# Fulham FC None - None Manchester City FC (TIMED)
# Ipswich Town FC None - None West Ham United FC (TIMED)
# Liverpool FC None - None Crystal Palace FC (TIMED)
# Manchester United FC None - None Aston Villa FC (TIMED)
# Newcastle United FC None - None Everton FC (TIMED)
# Nottingham Forest FC None - None Chelsea FC (TIMED)
# Southampton FC None - None Arsenal FC (TIMED)
# Tottenham Hotspur FC None - None Brighton & Hove Albion FC (TIMED)
# Wolverhampton Wanderers FC None - None Brentford FC (TIMED)

# %% [markdown]
# ## Prueba Partidos Champions League convirtiendo a pandas df

# %%
import requests
import pandas as pd

# Define the API endpoint and your API token
api_url = 'https://api.football-data.org/v4/competitions/CL/matches'
headers = {'X-Auth-Token': '02c8648f03b64960af5df010463cc253'}  # Replace with your actual API token

# Send a GET request to the API
response = requests.get(api_url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    matches = data.get('matches', [])
    
    # Extracting relevant match information
    match_list = []
    for match in matches:
        match_list.append({
            "stage": match.get('stage'),
            "Date": match['utcDate'],
            "Home Team": match['homeTeam']['name'],
            "Home Score": match['score']['fullTime']['home'],
            "Away Score": match['score']['fullTime']['away'],
            "Away Team": match['awayTeam']['name'],
            "Status": match['status']
        })
    
    # Convert to pandas DataFrame
    df = pd.DataFrame(match_list)

    stages = []
    for index, row in df.iterrows():
        if {"stage": row["stage"]} not in stages:
            stages.append({"stage": row["stage"]})
    
    # Display the DataFrame
    print(stages)
else:
    print(f"Request failed with status code {response.status_code}: {response.text}")
# Out:
# [{'stage': 'LEAGUE_STAGE'}, {'stage': 'PLAYOFFS'}, {'stage': 'LAST_16'}, {'stage': 'QUARTER_FINALS'}, {'stage': 'SEMI_FINALS'}, {'stage': 'FINAL'}]

# %% [markdown]
# ## Prueba Temporadas Mundial de la FIFA salvando archivo csv

# %%
import requests
import pandas as pd

# Define the API endpoint and your API token
api_url = 'https://api.football-data.org/v4/competitions/WC'
headers = {'X-Auth-Token': '9b3bba4a9ab24ab68b70aac4677adbbe'}  # Replace with your actual API token

# Send a GET request to the API
response = requests.get(api_url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    try:
        data = response.json()
        
        if 'seasons' not in data:
            print("No 'seasons' key found in the response. Check if your API token is valid.")
        else:
            seasons = data['seasons']
            
            # Extract relevant information for each season
            season_list = []
            for season in seasons:
                winner = season.get('winner', None)
                winner_name = winner['name'] if winner else 'No winner yet'
                
                season_list.append({
                    "Season ID": season['id'],
                    "Start Date": season['startDate'],
                    "End Date": season['endDate'],
                    "Current Matchday": season.get('currentMatchday', 'N/A'),
                    "Winner": winner_name
                })

            # Convert the list to a pandas DataFrame
            df = pd.DataFrame(season_list)
            
            # Display the DataFrame
            print(df)
            
            # Optionally, save the DataFrame to a CSV file
            df.to_csv('worldcup_seasons.csv', index=False)
            print("Data saved to 'worldcup_seasons.csv'.")
    except ValueError:
        print("Failed to parse the response as JSON. Response Text:", response.text)
else:
    print(f"Request failed with status code {response.status_code}: {response.text}")
# Out:
#     Season ID  Start Date    End Date  Current Matchday     Winner
# 0        1382  2022-11-20  2022-12-18               8.0  Argentina
# 1           1  2018-06-14  2018-07-15               3.0     France
# 2         464  2014-06-11  2014-07-12               NaN    Germany
# 3         770  2010-06-10  2010-07-10               NaN      Spain
# 4         771  2006-06-08  2006-07-08               NaN      Italy
# 5         772  2002-05-30  2002-06-29               NaN     Brazil
# 6         773  1998-06-09  1998-07-11               NaN     France
# 7         774  1994-06-16  1994-07-16               NaN     Brazil
# 8         775  1990-06-07  1990-07-07               NaN    Germany
# 9         776  1986-05-30  1986-06-28               NaN  Argentina
# 10        777  1982-06-12  1982-07-10               NaN      Italy
# 11        778  1978-05-31  1978-06-24               NaN  Argentina
# 12        779  1974-06-12  1974-07-06               NaN    Germany
# 13        780  1970-05-30  1970-06-20               NaN     Brazil
# 14        781  1966-07-10  1966-07-29               NaN    England
# 15        782  1962-05-29  1962-06-16               NaN     Brazil
# 16        783  1958-06-07  1958-06-28               NaN     Brazil
# 17        784  1954-06-15  1954-07-03               NaN    Germany
# 18        785  1950-06-23  1950-07-15               NaN    Uruguay
# 19        786  1938-06-03  1938-06-18               NaN      Italy
# 20        787  1934-05-26  1934-06-09               NaN      Italy
# 21        788  1930-07-12  1930-07-29               NaN    Uruguay
# Data saved to 'premier_league_seasons.csv'.
